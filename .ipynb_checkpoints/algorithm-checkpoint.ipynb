# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.linear_model import LinearRegression
import math
from tqdm.auto import tqdm

# Turning off the warning message
pd.set_option('mode.chained_assignment', None)

# %% [markdown]
# ### Loading S&P500 levels and dividends data

# %%
df_snp500 = pd.read_csv(os.path.join('/Users/skim/Desktop/Code/Quant/data/snp500.csv'))
df_snp500 = df_snp500[['Date','Symbol','Close']]
start_date = '2020-01-01'
end_date = '2022-12-31'
df_snp500 = df_snp500.loc[(df_snp500.Date > start_date) & (df_snp500.Date < end_date)]
df_snp500_wide = df_snp500.pivot(index='Date', columns='Symbol', values='Close')
print(f'There are {sum(df_snp500_wide.isna().sum() > 0)} stocks with missing data')
# Out:
# There are 5 stocks with missing data

# %%
df_dividends = pd.read_csv(os.path.join('/Users/skim/Desktop/Code/Quant/data/snp500_dividends.csv'))
df_dividends = df_dividends.loc[(df_dividends.Date > '2020-01-01') & (df_dividends.Date < '2022-12-31')]
df_dividends.set_index(df_dividends.Date, inplace = True)
df_dividends.drop(columns = ['Date'], inplace = True)
df_dividends = df_dividends.loc[:, list(df_snp500_wide.columns)]

# %%
# Remove columns(stocks) with NAs
df_snp500_wide = df_snp500_wide.loc[:,(df_snp500_wide.isna().sum() == 0).values]
print(f'There are {df_snp500_wide.shape[1]} stocks with no missing data')
# Out:
# There are 496 stocks with no missing data

# %%
df_data = df_snp500_wide

# %%
def compute_return(data):
    '''
    Computes daily returns for each column(stock).
    '''
    df_return = (data-data.shift(1))/data
    df_return = df_return.drop(df_return.index[0])
    return df_return


def PCA_fator(df_return, delay, fac_num):
    '''
    Returns eigenvectors and eigenportfolio weights.
    
    ## Notations ## 
    N: Number of stocks
    T: Length of dataframe
    W: delay = 252
    P: Number of PCA factors
    
    ## Variables ##
    df_return: ((T-1) x N) dataframe of daily returns
    delay: Number of days used for PCA computation
    fac_num: number of PCA factors
    '''
    mean = df_return.mean(axis = 0) # (N x 1), Mean return of stocks
    std = df_return.std(axis = 0) # (N x 1), Sample standard deviation of stock returns
    std_ret = (df_return-mean)/std # (N x 1), Standardised return
    
    pca = PCA(n_components = fac_num)
    pca.fit(std_ret[0:delay]) # Fit PCA with first T observations
    pf_weight = pd.DataFrame(pca.components_) # (P x N), P eigenvectors(rows) of length N
    pf_weight.columns = std.index
    pf_weight = pf_weight/std # Each row is an eigenvector/sample standard deviation for factor j, representing eigenportfolio weights for stocks
    factor_ret = pd.DataFrame(df_return@pf_weight.transpose(), index = df_return.index) # (T x P), Eigenportfolio returns
    return factor_ret, pf_weight

# %% [markdown]
# For stock $i$, we fit below PCR regression, and obtain coefficients and residual process.
# $$ \epsilon_{i,t} = \text{stock return}_{i,t} - \hat{\text{stock return}_{t, p}}$$
# $$ = \text{stock return}_{i,t} - (\alpha + \sum_{p=1}^{P} \beta_{p,i} * \text{eigenportfolio return}_{t, p})$$

# %%
def find_Residue(df_return, ret_factorret):
    '''
    Returns OLS coefficients of residual process
    
    ## Notations ## 
    N: Number of stocks
    w: backtesting window = 60
    P: Number of PCA factors
    
    ## Variables ##
    df_return: ((w-1) x N), dataframe of daily returns
    ret_factorret: ((w-1) x N), eigenportfolio returns
    res: ((w-1) x N), 
    coef: (P x N), each column contains OLS coefficients for PCA factor regression
    '''
    T, P = ret_factorret.shape
    res = pd.DataFrame(columns = df_return.columns, index = df_return.index)
    coef = pd.DataFrame(columns = df_return.columns, index = range(P)) 
    ols = LinearRegression()
    for i in df_return.columns: 
        ols.fit(ret_factorret, df_return[i]) # fit (w x P) eigenportfolio returns data to (w x 1) stock i returns data.
        res[i] = df_return[i] - ols.intercept_ - np.dot(ret_factorret, ols.coef_) # Each column of res is the daily residual
        coef[i] = ols.coef_
    return res, coef

# %% [markdown]
# We select stocks with mean-reversion times less than 1/2 period, i.e. $\kappa > \frac{252}{30} = 8.4$, and the s-score is for stock i is given by $$ s_i = \frac{\epsilon_i(t)-m_i}{\sigma_{\text{eq,i}}} $$
# where $m_i$ is sample mean of cumulative residuals, and $\sigma_{\text{eq,i}} = \frac{\sigma_i}{\sqrt{2 \kappa_i}}$

# %%
def find_Target_sscores(res, k):
    '''
    Compute trading signal, s-score.
    
    ## Notations ## 
    N: Number of stocks
    w: backtesting window = 60
    P: Number of PCA factors
    
    ## Variables ##
    df_return: ((w-1) x N), dataframe of daily returns
    ret_factorret: ((w-1) x N), eigenportfolio returns
    res: ((w-1) x N), 
    coef: (P x N), each column contains OLS coefficients for PCA factor regression
    s_score: (N x 1), s-score for each stock 
    '''
    cum_res = res.cumsum() # ((w-1) x N) df of cumulative residuals
    m = pd.Series(index = cum_res.columns, dtype = 'float64') # (N x 1), mean 
    sigma_eq = pd.Series(index = cum_res.columns, dtype = 'float64') # (N x 1) series
    for i in cum_res.columns: # For each stock 
        b = cum_res[i].autocorr() # A scalar of autocorrelation of first lag 
        if -math.log(b) * 252 > k: 
            '''
            The higher the first order autocorr, the lower the value of -math.log(b) * 252.
            This is a measure of mean-reversion time, and we choose stock i with mean-reversion times less than 0.5 period(30 days),
            i.e. k = 252/30 = 8.4
            '''
            temp = (cum_res[i]-cum_res[i].shift(1) * b)[1:] # AR(1) prediction residuals of cumulative residuals = Current cumulative residual - (b * previous cumulative residual)
            a = temp.mean()
            cosi = temp - a
            m[i] = a/(1-b)
            sigma_eq[i] = math.sqrt(cosi.var()/(1-b*b))
    m = m.dropna()
    m = m - m.mean()
    sigma_eq = sigma_eq.dropna()
    s_score = -m / sigma_eq
    return s_score

# %%
def backtest():
    '''
    ## Notations ## 
    N: Number of stocks
    T: Length of dataframe
    W: delay
    P: Number of PCA factors
    '''
    
    sbo = 2 # buy to open threshold
    sso = 2 # sell to open
    sbc = 0.75 # buy to close
    ssc = 0.5 # sell to close
    leverage = 5
    tran_cost = 0.0005
    r = 0.00
    window = 60
    k = 8.4
    P = 15

    delay = 252
    start_val = 100
    pnl = pd.Series(start_val, index = df_data.index[delay-1:]) # pnl for OOS backtesting
    
    position_stock = pd.DataFrame(0, columns = df_data.columns, index = ['stock'] + list(range(15))) # ((P+1) x N) df
    position_stock_before = pd.Series(0, index = df_data.columns) # (N x 1) series
    
    daily_ret = compute_return(df_data)
    fac_ret, weights = PCA_fator(daily_ret, delay, P)

    # (W-1) to T-1
    for t in tqdm(range(delay-1, len(df_data.index)-1)):
    # find the window price of all stocks
        price_t = df_snp500_wide[(t-window):(t+1)]
        ret_t = compute_return(price_t)
        # Only pick corresponding w days window data from ((T x P) eigenportfolio df)
        fac_ret_t = fac_ret[(t-window+1):(t+1)]
        res_t, coef_t = find_Residue(ret_t, fac_ret_t)
        target = find_Target_sscores(res_t, k)

        for i in position_stock.columns:
            if not i in target.index: # If i is dropped during find target s-score process, i.e. the mean reversion time was too long,
                if position_stock[i]['stock'] != 0: # If the current position is non-zero
                    position_stock[i] = 0 # clear the position
            else: # if mean reversion time was short enough,
                if position_stock[i]['stock'] == 0: # if the current position is zero
                    if target[i] < -sbo: # if the current signal is lower than the buy to open threshold
                        position_stock[i]['stock'] = leverage # i.e. set the stock row as 1, indicating we have a position in the stock
                        position_stock[i][1:] = -leverage * coef_t[i] 
                    elif target[i] >sso:
                        position_stock[i]['stock'] = - leverage
                        position_stock[i][1:] = leverage * coef_t[i]
                elif position_stock[i][0] > 0 and target[i] > -ssc: # If the current position is positive, and we have a sell to close signal
                    position_stock[i] = 0
                elif position_stock[i][0] < 0 and target[i] < sbc: # If the current position is negative, and we have a buy to close signal
                    position_stock[i] = 0
            dps_t = df_dividends.iloc[t+1]
            pri_t = df_snp500_wide.iloc[t+1]
            temp = (dps_t/pri_t).fillna(0)
            position_stock_temp = pd.Series(0,index = df_snp500_wide.columns)
            fac_sum = position_stock.sum(axis = 1)[1:]
            for i in weights.columns:
                position_stock_temp = sum(weights[i] * fac_sum)
            position_stock_temp = position_stock_temp + position_stock.iloc[0]
            change = sum(abs(position_stock_temp - position_stock_before))
            position_stock_before = position_stock_temp
            pnl.iloc[t-delay + 2] = pnl.iloc[t-delay + 1] * ( 1 + r /252.0) + np.dot(position_stock.loc['stock'], daily_ret.iloc[t]) + np.dot(position_stock.sum(axis = 1)[1:], fac_ret.iloc[t]) - position_stock.sum().sum() * r /252.0 - change * tran_cost
        print (f'Portfolio value on day {t}: {pnl.iloc[t-delay + 2]}')

# %%
backtest()
# Out:
#   0%|          | 0/504 [00:00<?, ?it/s]
# Portfolio value on day 251: 99.70733431007702
# Portfolio value on day 252: 99.70138432850446
# Portfolio value on day 253: 100.46535776187797
# Portfolio value on day 254: 101.06978840116375
# Portfolio value on day 255: 101.89892585780376
# Portfolio value on day 256: 102.12448770687473
# Portfolio value on day 257: 102.23117469924453
# Portfolio value on day 258: 102.90505357328901
# Portfolio value on day 259: 103.48248408227808
# Portfolio value on day 260: 102.94604406291941
# Portfolio value on day 261: 103.60007824053963
# Portfolio value on day 262: 103.08032240630266
# Portfolio value on day 263: 103.14818986926656
# Portfolio value on day 264: 103.12986405147723
# Portfolio value on day 265: 103.29554121442527
# Portfolio value on day 266: 102.45155766632448
# Portfolio value on day 267: 103.97953756793815
# Portfolio value on day 268: 107.9648305681116
# Portfolio value on day 269: 110.189099880986
# Portfolio value on day 270: 110.04121381573614
# Portfolio value on day 271: 108.62455328419662
# Portfolio value on day 272: 107.7874144634775
# Portfolio value on day 273: 109.13730735131806
# Portfolio value on day 274: 109.77617997844752
# Portfolio value on day 275: 109.0846693912392
# Portfolio value on day 276: 109.81739620535303
# Portfolio value on day 277: 109.72548197124037
# Portfolio value on day 278: 109.78792610801939
# Portfolio value on day 279: 109.553517679121
# Portfolio value on day 280: 110.29419397299479
# Portfolio value on day 281: 110.58374771697201
# Portfolio value on day 282: 110.99680244061457
# Portfolio value on day 283: 110.36319445340878
# Portfolio value on day 284: 112.46566321902702
# Portfolio value on day 285: 113.86140751726077
# Portfolio value on day 286: 113.86083819447494
# Portfolio value on day 287: 114.61804066473238
# Portfolio value on day 288: 112.81991671174453
# Portfolio value on day 289: 113.97767712644723
# Portfolio value on day 290: 114.83598423967827
# Portfolio value on day 291: 114.80053953393377
# Portfolio value on day 292: 114.00850348609231
# Portfolio value on day 293: 113.19338001887013
# Portfolio value on day 294: 113.23384441009277
# Portfolio value on day 295: 112.19351345065776
# Portfolio value on day 296: 117.58431565044525
# Portfolio value on day 297: 116.85372208698628
# Portfolio value on day 298: 117.76448118983876
# Portfolio value on day 299: 115.77862050446475
# Portfolio value on day 300: 116.49559236658578
# Portfolio value on day 301: 116.65983394493644
# Portfolio value on day 302: 117.06755404602234
# Portfolio value on day 303: 116.10069583682842
# Portfolio value on day 304: 116.41029216076603
# Portfolio value on day 305: 116.73919118684876
# Portfolio value on day 306: 116.19867963855975
# Portfolio value on day 307: 115.89331205701329
# Portfolio value on day 308: 115.75631285158084
# Portfolio value on day 309: 115.85421565250152
# Portfolio value on day 310: 115.57216161447165
# Portfolio value on day 311: 117.22150132912033
# Portfolio value on day 312: 117.65842682911637
# Portfolio value on day 313: 118.52399955105572
# Portfolio value on day 314: 117.20824018860968
# Portfolio value on day 315: 117.66957122373051
# Portfolio value on day 316: 116.37649511140226
# Portfolio value on day 317: 116.06224668845505
# Portfolio value on day 318: 115.23269062306726
# Portfolio value on day 319: 114.43437486906608
# Portfolio value on day 320: 113.9396017432989
# Portfolio value on day 321: 115.09318832056827
# Portfolio value on day 322: 114.93595761004161
# Portfolio value on day 323: 114.66936091454504
# Portfolio value on day 324: 114.1718946581885
# Portfolio value on day 325: 112.78359233003545
# Portfolio value on day 326: 112.57446726459837
# Portfolio value on day 327: 113.0518431678744
# Portfolio value on day 328: 111.91798725310748
# Portfolio value on day 329: 112.38857548159693
# Portfolio value on day 330: 113.25882390441085
# Portfolio value on day 331: 114.12114056425906
# Portfolio value on day 332: 112.91299673254217
# Portfolio value on day 333: 113.01862155289287
# Portfolio value on day 334: 112.39173149181833
# Portfolio value on day 335: 112.42912152082538
# Portfolio value on day 336: 112.3991752406329
# Portfolio value on day 337: 110.85927697953251
# Portfolio value on day 338: 110.50885530635986
# Portfolio value on day 339: 110.3435859306913
# Portfolio value on day 340: 111.56169219931671
# Portfolio value on day 341: 111.01460217471026
# Portfolio value on day 342: 111.09666402311166
# Portfolio value on day 343: 111.45742366900856
# Portfolio value on day 344: 111.30960388235918
# Portfolio value on day 345: 112.13370203649816
# Portfolio value on day 346: 111.93646509472848
# Portfolio value on day 347: 111.3671210659003
# Portfolio value on day 348: 111.9559400552521
# Portfolio value on day 349: 111.70166370849172
# Portfolio value on day 350: 111.68206298537856
# Portfolio value on day 351: 111.58023091245003
# Portfolio value on day 352: 112.09743963018197
# Portfolio value on day 353: 112.36656206814366
# Portfolio value on day 354: 111.34842190802512
# Portfolio value on day 355: 112.56502143444197
# Portfolio value on day 356: 112.82068036177296
# Portfolio value on day 357: 112.92552599799116
# Portfolio value on day 358: 114.44727489710708
# Portfolio value on day 359: 114.408442120932
# Portfolio value on day 360: 116.18484567252798
# Portfolio value on day 361: 117.46919101353782
# Portfolio value on day 362: 116.6804940246324
# Portfolio value on day 363: 116.42975485317231
# Portfolio value on day 364: 115.31799089556219
# Portfolio value on day 365: 115.98387976193007
# Portfolio value on day 366: 119.53387888661143
# Portfolio value on day 367: 120.77661306278362
# Portfolio value on day 368: 118.24000785927909
# Portfolio value on day 369: 117.35918415968447
# Portfolio value on day 370: 117.239992046079
# Portfolio value on day 371: 115.44058411518692
# Portfolio value on day 372: 114.87196647333474
# Portfolio value on day 373: 115.66309754424374
# Portfolio value on day 374: 114.83299447745756
# Portfolio value on day 375: 114.49681178057823
# Portfolio value on day 376: 114.66247378960225
# Portfolio value on day 377: 114.83278445045651
# Portfolio value on day 378: 116.41687168129855
# Portfolio value on day 379: 115.94104373995069
# Portfolio value on day 380: 116.79869539105157
# Portfolio value on day 381: 114.86347569186528
# Portfolio value on day 382: 114.4278968818006
# Portfolio value on day 383: 115.19379933592965
# Portfolio value on day 384: 113.75785631233076
# Portfolio value on day 385: 113.17799900842738
# Portfolio value on day 386: 113.08243775181987
# Portfolio value on day 387: 115.43291269880503
# Portfolio value on day 388: 112.68508573365816
# Portfolio value on day 389: 113.43780290220246
# Portfolio value on day 390: 113.34467499861863
# Portfolio value on day 391: 111.47107379208714
# Portfolio value on day 392: 112.08378540135269
# Portfolio value on day 393: 111.4744442434554
# Portfolio value on day 394: 112.04305813032208
# Portfolio value on day 395: 112.49637490633881
# Portfolio value on day 396: 112.38811823249719
# Portfolio value on day 397: 112.3123722557148
# Portfolio value on day 398: 112.06252647727483
# Portfolio value on day 399: 111.02733928516456
# Portfolio value on day 400: 111.05520062992979
# Portfolio value on day 401: 111.79822595325594
# Portfolio value on day 402: 111.50026810142911
# Portfolio value on day 403: 110.53181896137663
# Portfolio value on day 404: 110.67410923100577
# Portfolio value on day 405: 111.0317004690618
# Portfolio value on day 406: 110.58298791978416
# Portfolio value on day 407: 110.14473545157479
# Portfolio value on day 408: 109.62872921067272
# Portfolio value on day 409: 109.17076269678793
# Portfolio value on day 410: 108.42991693201698
# Portfolio value on day 411: 108.76144512872006
# Portfolio value on day 412: 111.14561602833315
# Portfolio value on day 413: 112.51840143738646
# Portfolio value on day 414: 112.50873238650418
# Portfolio value on day 415: 112.27555768255681
# Portfolio value on day 416: 114.24611299062416
# Portfolio value on day 417: 114.98057389930828
# Portfolio value on day 418: 115.02232775796209
# Portfolio value on day 419: 115.756548665678
# Portfolio value on day 420: 116.40518529242637
# Portfolio value on day 421: 116.90140362513374
# Portfolio value on day 422: 116.1514199630963
# Portfolio value on day 423: 116.93208932384042
# Portfolio value on day 424: 116.48557389770214
# Portfolio value on day 425: 117.36242751726286
# Portfolio value on day 426: 116.04082432919063
# Portfolio value on day 427: 117.06114522193988
# Portfolio value on day 428: 116.91579935531803
# Portfolio value on day 429: 116.91105784096973
# Portfolio value on day 430: 115.92911706587334
# Portfolio value on day 431: 115.69310276605015
# Portfolio value on day 432: 116.87006344225061
# Portfolio value on day 433: 115.85475542916772
# Portfolio value on day 434: 115.03791125612295
# Portfolio value on day 435: 113.42720361592458
# Portfolio value on day 436: 111.6861278740919
# Portfolio value on day 437: 113.60758733200501
# Portfolio value on day 438: 113.75902782653858
# Portfolio value on day 439: 113.79231314719469
# Portfolio value on day 440: 111.91925659444695
# Portfolio value on day 441: 110.74683557762901
# Portfolio value on day 442: 111.51258325545562
# Portfolio value on day 443: 112.8455423793843
# Portfolio value on day 444: 112.8405529618963
# Portfolio value on day 445: 112.21153765584984
# Portfolio value on day 446: 111.9849529052337
# Portfolio value on day 447: 110.4010581210805
# Portfolio value on day 448: 109.78354015619884
# Portfolio value on day 449: 109.15211578335541
# Portfolio value on day 450: 109.5804323195871
# Portfolio value on day 451: 109.44154817272829
# Portfolio value on day 452: 109.26478083208124
# Portfolio value on day 453: 109.03417580819092
# Portfolio value on day 454: 109.74644837141607
# Portfolio value on day 455: 109.61170722066393
# Portfolio value on day 456: 109.45310142354465
# Portfolio value on day 457: 110.17929077519891
# Portfolio value on day 458: 111.03216570488026
# Portfolio value on day 459: 110.56029596821332
# Portfolio value on day 460: 110.49854900088872
# Portfolio value on day 461: 109.82442535555442
# Portfolio value on day 462: 110.75224408005538
# Portfolio value on day 463: 109.65893196665846
# Portfolio value on day 464: 108.27748211549952
# Portfolio value on day 465: 109.75897724922429
# Portfolio value on day 466: 110.64749624615634
# Portfolio value on day 467: 110.76597045322563
# Portfolio value on day 468: 110.37484590686948
# Portfolio value on day 469: 108.65320400741565
# Portfolio value on day 470: 109.3930929789801
# Portfolio value on day 471: 109.53845289505323
# Portfolio value on day 472: 109.07197973530613
# Portfolio value on day 473: 109.20899203617178
# Portfolio value on day 474: 108.25410087853294
# Portfolio value on day 475: 107.71522104924401
# Portfolio value on day 476: 108.6614544920265
# Portfolio value on day 477: 108.10653393506843
# Portfolio value on day 478: 107.38365271109338
# Portfolio value on day 479: 107.36139413985643
# Portfolio value on day 480: 107.42001957465313
# Portfolio value on day 481: 107.11241372975938
# Portfolio value on day 482: 107.12865040539126
# Portfolio value on day 483: 107.60289503871235
# Portfolio value on day 484: 107.7490056946781
# Portfolio value on day 485: 107.38849437173192
# Portfolio value on day 486: 107.67032051600513
# Portfolio value on day 487: 107.78972478985423
# Portfolio value on day 488: 107.44793864773567
# Portfolio value on day 489: 106.71424357718286
# Portfolio value on day 490: 105.87211884495801
# Portfolio value on day 491: 106.55450153271639
# Portfolio value on day 492: 104.688018245801
# Portfolio value on day 493: 101.8013522958055
# Portfolio value on day 494: 105.49853064118118
# Portfolio value on day 495: 105.39606841803791
# Portfolio value on day 496: 107.99636268837712
# Portfolio value on day 497: 107.89632837446216
# Portfolio value on day 498: 107.82855771530839
# Portfolio value on day 499: 107.13918648899708
# Portfolio value on day 500: 106.20801341737321
# Portfolio value on day 501: 105.89854211857411
# Portfolio value on day 502: 105.72791340457073
# Portfolio value on day 503: 104.85060926015952
# Portfolio value on day 504: 105.4714305260019
# Portfolio value on day 505: 103.76984393752637
# Portfolio value on day 506: 103.01217377117571
# Portfolio value on day 507: 102.62475565597461
# Portfolio value on day 508: 101.014655842509
# Portfolio value on day 509: 102.40374196266775
# Portfolio value on day 510: 104.08745745684584
# Portfolio value on day 511: 104.94482464743835
# Portfolio value on day 512: 102.29497040076113
# Portfolio value on day 513: 102.18976684787789
# Portfolio value on day 514: 102.50545944870014
# Portfolio value on day 515: 103.87012841017774
# Portfolio value on day 516: 104.20722116063807
# Portfolio value on day 517: 104.29637173522403
# Portfolio value on day 518: 105.02632631528897
# Portfolio value on day 519: 105.43870546609172
# Portfolio value on day 520: 106.04842283045723
# Portfolio value on day 521: 106.17067700361751
# Portfolio value on day 522: 106.16258146754028
# Portfolio value on day 523: 106.12219596338882
# Portfolio value on day 524: 106.32291187315022
# Portfolio value on day 525: 105.69154203173498
# Portfolio value on day 526: 105.79220221612844
# Portfolio value on day 527: 105.59179906581798
# Portfolio value on day 528: 105.6468441147077
# Portfolio value on day 529: 104.67703563730691
# Portfolio value on day 530: 103.97586541237088
# Portfolio value on day 531: 101.03950898517434
# Portfolio value on day 532: 101.51166671211992
# Portfolio value on day 533: 100.97819672627251
# Portfolio value on day 534: 99.79404656847689
# Portfolio value on day 535: 100.09885708178129
# Portfolio value on day 536: 100.37117068938508
# Portfolio value on day 537: 100.24317081840077
# Portfolio value on day 538: 100.87093168586887
# Portfolio value on day 539: 100.86153416279267
# Portfolio value on day 540: 100.46842701034988
# Portfolio value on day 541: 102.40925269602917
# Portfolio value on day 542: 100.26067805365057
# Portfolio value on day 543: 100.05056741741991
# Portfolio value on day 544: 101.06622728711217
# Portfolio value on day 545: 101.83132750442029
# Portfolio value on day 546: 101.62040630349509
# Portfolio value on day 547: 100.43937510618132
# Portfolio value on day 548: 97.38869763247
# Portfolio value on day 549: 98.37578659707127
# Portfolio value on day 550: 99.11842561042967
# Portfolio value on day 551: 98.9647508555772
# Portfolio value on day 552: 100.91159541057718
# Portfolio value on day 553: 100.40429883347166
# Portfolio value on day 554: 100.21010289711643
# Portfolio value on day 555: 102.88215710651268
# Portfolio value on day 556: 103.0150883473089
# Portfolio value on day 557: 104.64730366736134
# Portfolio value on day 558: 102.99876310226868
# Portfolio value on day 559: 103.78196079759088
# Portfolio value on day 560: 102.85224577349028
# Portfolio value on day 561: 103.79702721381125
# Portfolio value on day 562: 103.07368819932695
# Portfolio value on day 563: 103.04408114312072
# Portfolio value on day 564: 102.8298107928037
# Portfolio value on day 565: 101.74656641286012
# Portfolio value on day 566: 101.84883870174677
# Portfolio value on day 567: 100.7069055839419
# Portfolio value on day 568: 101.83418562746112
# Portfolio value on day 569: 103.90104130232002
# Portfolio value on day 570: 105.79047984739177
# Portfolio value on day 571: 106.94440847115986
# Portfolio value on day 572: 107.41119356672617
# Portfolio value on day 573: 107.11580359702401
# Portfolio value on day 574: 106.74992884398603
# Portfolio value on day 575: 106.75858714622646
# Portfolio value on day 576: 107.0979282092591
# Portfolio value on day 577: 107.09028082297111
# Portfolio value on day 578: 107.12882871484251
# Portfolio value on day 579: 107.14047288107446
# Portfolio value on day 580: 107.31430037334644
# Portfolio value on day 581: 107.09128021827664
# Portfolio value on day 582: 107.07543434871624
# Portfolio value on day 583: 107.56100749294895
# Portfolio value on day 584: 107.25281612379038
# Portfolio value on day 585: 108.40195814237876
# Portfolio value on day 586: 109.08566645670238
# Portfolio value on day 587: 108.91857820458355
# Portfolio value on day 588: 108.65565314554847
# Portfolio value on day 589: 108.4952525774171
# Portfolio value on day 590: 107.71680344242951
# Portfolio value on day 591: 108.01778566603585
# Portfolio value on day 592: 109.56894526876711
# Portfolio value on day 593: 109.42100654908839
# Portfolio value on day 594: 108.58410671085196
# Portfolio value on day 595: 108.03209366446333
# Portfolio value on day 596: 107.99273205568386
# Portfolio value on day 597: 107.93949349384202
# Portfolio value on day 598: 113.04274526393648
# Portfolio value on day 599: 113.23069000484561
# Portfolio value on day 600: 113.79415653853634
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 backtest()
#
# Cell In[15], line 63, in backtest()
#      61 fac_sum = position_stock.sum(axis = 1)[1:]
#      62 for i in weights.columns:
# ---> 63     position_stock_temp = sum(weights[i] * fac_sum)
#      64 position_stock_temp = position_stock_temp + position_stock.iloc[0]
#      65 change = sum(abs(position_stock_temp - position_stock_before))
#
# File ~/miniforge3/envs/bayes/lib/python3.9/site-packages/pandas/core/ops/common.py:72, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      68             return NotImplemented
#      70 other = item_from_zerodim(other)
# ---> 72 return method(self, other)
#
# File ~/miniforge3/envs/bayes/lib/python3.9/site-packages/pandas/core/arraylike.py:118, in OpsMixin.__mul__(self, other)
#     116 @unpack_zerodim_and_defer("__mul__")
#     117 def __mul__(self, other):
# --> 118     return self._arith_method(other, operator.mul)
#
# File ~/miniforge3/envs/bayes/lib/python3.9/site-packages/pandas/core/series.py:6258, in Series._arith_method(self, other, op)
#    6257 def _arith_method(self, other, op):
# -> 6258     self, other = ops.align_method_SERIES(self, other)
#    6259     return base.IndexOpsMixin._arith_method(self, other, op)
#
# File ~/miniforge3/envs/bayes/lib/python3.9/site-packages/pandas/core/ops/__init__.py:160, in align_method_SERIES(left, right, align_asobject)
#     154 # ToDo: Different from align_method_FRAME, list, tuple and ndarray
#     155 # are not coerced here
#     156 # because Series has inconsistencies described in #13637
#     158 if isinstance(right, ABCSeries):
#     159     # avoid repeated alignment
# --> 160     if not left.index.equals(right.index):
#     162         if align_asobject:
#     163             # to keep original value's dtype for bool ops
#     164             left = left.astype(object)
#
# File ~/miniforge3/envs/bayes/lib/python3.9/site-packages/pandas/core/indexes/range.py:547, in RangeIndex.equals(self, other)
#     545 if isinstance(other, RangeIndex):
#     546     return self._range == other._range
# --> 547 return super().equals(other)
#
# File ~/miniforge3/envs/bayes/lib/python3.9/site-packages/pandas/core/indexes/base.py:5529, in Index.equals(self, other)
#    5526 if not isinstance(other, Index):
#    5527     return False
# -> 5529 if is_object_dtype(self.dtype) and not is_object_dtype(other.dtype):
#    5530     # if other is not object, use other's logic for coercion
#    5531     return other.equals(self)
#    5533 if isinstance(other, ABCMultiIndex):
#    5534     # d-level MultiIndex can equal d-tuple Index
#
# File ~/miniforge3/envs/bayes/lib/python3.9/site-packages/pandas/core/dtypes/common.py:189, in is_object_dtype(arr_or_dtype)
#     162 def is_object_dtype(arr_or_dtype) -> bool:
#     163     """
#     164     Check whether an array-like or dtype is of the object dtype.
#     165
#    (...)
#     187     False
#     188     """
# --> 189     return _is_dtype_type(arr_or_dtype, classes(np.object_))
#
# File ~/miniforge3/envs/bayes/lib/python3.9/site-packages/pandas/core/dtypes/common.py:1610, in _is_dtype_type(arr_or_dtype, condition)
#    1608 # fastpath
#    1609 if isinstance(arr_or_dtype, np.dtype):
# -> 1610     return condition(arr_or_dtype.type)
#    1611 elif isinstance(arr_or_dtype, type):
#    1612     if issubclass(arr_or_dtype, ExtensionDtype):
#
# KeyboardInterrupt:
